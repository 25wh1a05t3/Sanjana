# %%
def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()
# Out:
# Hello! Welcome to Python Functions.

# %%
def greet(age):
    print(f"ALia is, {age} years old")

greet("12")
greet(18)
# Out:
# ALia is, 12 years old
# ALia is, 18 years old

# %%
def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")
# Out:
# Welcome, Guest!
# Welcome, Ravi!

# %%
def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")
# Out:
# Names passed: ('Alice', 'bob', 'Charlie')
# Hello Alice
# Hello bob
# Hello Charlie

# %%
def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")
# Out:
# User Info:
# name = Alice
# age = 25
# city = Delhi

# %%
def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))
# Out:
# Square of 4: 16
