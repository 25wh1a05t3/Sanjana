# %%
import datetime
import random

print("\n--- Task 1: Data Generation and Basic Structures ---")

# Global Data
DEVICE_TYPES = [
    'Temperature_Sensor',
    'Humidity_Sensor',
    'Pressure_Sensor',
    'Light_Sensor'
]

LOCATIONS = [
    'Lab1',
    'Lab2',
    'OfficeA',
    'OfficeB',
    'Warehouse'
]

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

# =====================================================
# Task 1.1 - Generate 100 simulated sensor readings
# =====================================================

raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(100):

    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    minimum, maximum = READING_RANGES[device_type]

    value = round(random.uniform(minimum, maximum), 2)

    timestamp = (
        start_time + datetime.timedelta(minutes=i)
    ).strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03d}"

    reading = (
        timestamp,
        device_id,
        device_type,
        location,
        value
    )

    raw_sensor_data.append(reading)

print("Total Sensor Readings:", len(raw_sensor_data))

# =====================================================
# Task 1.2 - Create Temperature Reading Dictionary List
# =====================================================

temperature_readings = []

for reading in raw_sensor_data:

    if reading[2] == "Temperature_Sensor":

        temperature_readings.append({

            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]

        })

print("Temperature Readings:", len(temperature_readings))

# =====================================================
# Task 1.3 - Create Set of Unique Locations
# =====================================================

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print("\nUnique Locations")
print(unique_locations)

# =====================================================
# Task 1.4 - Device Statistics Dictionary
# =====================================================

device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

for reading in raw_sensor_data:

    device = reading[2]
    value = reading[4]

    minimum, maximum = device_stats[device]

    minimum = min(minimum, value)
    maximum = max(maximum, value)

    device_stats[device] = (minimum, maximum)

print("\nDevice Statistics")

for device, stats in device_stats.items():
    print(f"{device} : Min = {stats[0]}, Max = {stats[1]}")

# =====================================================
# Task 1.5 - Indexing and Slicing
# =====================================================

print("\n--- Task 1.5: Advanced Indexing and Slicing ---")

sample_string = "PythonProgrammingIsFun"

# -------------------------------
# Task 1.5.1 - List Slicing
# -------------------------------

sliced_readings_1 = raw_sensor_data[9:20]

sliced_readings_2 = raw_sensor_data[::5]

print("\n10th to 20th Readings")
for item in sliced_readings_1:
    print(item)

print("\nEvery 5th Reading")
for item in sliced_readings_2:
    print(item)

# -------------------------------
# Task 1.5.2 - String Slicing
# -------------------------------

substring_1 = sample_string[6:17]

substring_2 = sample_string[:6][::-1]

print("\nSubstring 1 :", substring_1)
print("Substring 2 :", substring_2)

# -------------------------------
# Task 1.5.3 - Mixed Slicing
# -------------------------------

fifth_reading_device_type = raw_sensor_data[4][2]

device_type_suffix = fifth_reading_device_type[-6:]

print("\n5th Reading Device Type :", fifth_reading_device_type)
print("Last 6 Characters :", device_type_suffix)

print("\n--- Task 1 Completed Successfully ---")
# Out:
# --- Task 1: Data Generation and Basic Structures ---
# Total Sensor Readings: 100
# Temperature Readings: 28
#
# Unique Locations
# {'Warehouse', 'OfficeB', 'Lab1', 'Lab2', 'OfficeA'}
#
# Device Statistics
# Temperature_Sensor : Min = 18.07, Max = 29.81
# Humidity_Sensor : Min = 32.92, Max = 79.5
# Pressure_Sensor : Min = 980.57, Max = 1028.8
# Light_Sensor : Min = 103.68, Max = 949.45
#
# --- Task 1.5: Advanced Indexing and Slicing ---
#
# 10th to 20th Readings
# ('2026-08-06 14:05:56', 'DEV010', 'Light_Sensor', 'OfficeA', 790.99)
# ('2026-08-06 14:06:56', 'DEV011', 'Temperature_Sensor', 'Lab1', 27.76)
# ('2026-08-06 14:07:56', 'DEV012', 'Humidity_Sensor', 'Lab2', 70.14)
# ('2026-08-06 14:08:56', 'DEV013', 'Humidity_Sensor', 'Warehouse', 50.7)
# ('2026-08-06 14:09:56', 'DEV014', 'Pressure_Sensor', 'Warehouse', 1002.55)
# ('2026-08-06 14:10:56', 'DEV015', 'Humidity_Sensor', 'Warehouse', 51.56)
# ('2026-08-06 14:11:56', 'DEV016', 'Pressure_Sensor', 'Lab2', 1028.8)
# ('2026-08-06 14:12:56', 'DEV017', 'Temperature_Sensor', 'Warehouse', 29.81)
# ('2026-08-06 14:13:56', 'DEV018', 'Light_Sensor', 'OfficeA', 270.7)
# ('2026-08-06 14:14:56', 'DEV019', 'Humidity_Sensor', 'OfficeA', 51.88)
# ('2026-08-06 14:15:56', 'DEV020', 'Pressure_Sensor', 'Lab1', 996.64)
#
# Every 5th Reading
# ('2026-08-06 13:56:56', 'DEV001', 'Light_Sensor', 'Warehouse', 604.57)
# ('2026-08-06 14:01:56', 'DEV006', 'Light_Sensor', 'OfficeB', 272.33)
# ('2026-08-06 14:06:56', 'DEV011', 'Temperature_Sensor', 'Lab1', 27.76)
# ('2026-08-06 14:11:56', 'DEV016', 'Pressure_Sensor', 'Lab2', 1028.8)
# ('2026-08-06 14:16:56', 'DEV021', 'Temperature_Sensor', 'OfficeA', 24.78)
# ('2026-08-06 14:21:56', 'DEV026', 'Temperature_Sensor', 'OfficeB', 22.81)
# ('2026-08-06 14:26:56', 'DEV031', 'Humidity_Sensor', 'Lab1', 73.07)
# ('2026-08-06 14:31:56', 'DEV036', 'Pressure_Sensor', 'Lab1', 995.86)
# ('2026-08-06 14:36:56', 'DEV041', 'Temperature_Sensor', 'Warehouse', 19.61)
# ('2026-08-06 14:41:56', 'DEV046', 'Humidity_Sensor', 'Lab2', 35.88)
# ('2026-08-06 14:46:56', 'DEV051', 'Light_Sensor', 'OfficeA', 479.78)
# ('2026-08-06 14:51:56', 'DEV056', 'Light_Sensor', 'OfficeA', 690.04)
# ('2026-08-06 14:56:56', 'DEV061', 'Pressure_Sensor', 'Lab2', 1014.2)
# ('2026-08-06 15:01:56', 'DEV066', 'Pressure_Sensor', 'Lab1', 1008.85)
# ('2026-08-06 15:06:56', 'DEV071', 'Humidity_Sensor', 'OfficeA', 68.92)
# ('2026-08-06 15:11:56', 'DEV076', 'Light_Sensor', 'Lab1', 949.45)
# ('2026-08-06 15:16:56', 'DEV081', 'Pressure_Sensor', 'OfficeB', 1018.98)
# ('2026-08-06 15:21:56', 'DEV086', 'Pressure_Sensor', 'Warehouse', 1010.25)
# ('2026-08-06 15:26:56', 'DEV091', 'Pressure_Sensor', 'Lab2', 1013.75)
# ('2026-08-06 15:31:56', 'DEV096', 'Humidity_Sensor', 'OfficeA', 51.45)
#
# Substring 1 : Programming
# Substring 2 : nohtyP
#
# 5th Reading Device Type : Pressure_Sensor
# Last 6 Characters : Sensor
#
# --- Task 1 Completed Successfully ---
